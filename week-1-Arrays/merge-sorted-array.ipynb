# %%
nums1 = [1, 2, 3, 0, 0, 0]
nums2 = [2, 5, 6]

m = 3
n = 3

for i in range(6):
    for j in range(n):
        if nums1[i] > nums2[j]:
            temp = nums1[i]
            nums1[i] = nums2[j]
            nums2[j] = temp

        if nums1[i] == 0 and nums1[i] < nums1[j]:
            nums1[i] = nums2[j]


print(nums1)
# Out:
# [1, 2, 2, 3, 3, 3]

# %%
nums1 = [1, 2, 3, 0, 0, 0]
nums2 = [2, 5, 6]

m = 3
n = 3

for i in range(n):
    nums1[m+i]=nums2[i]
    
nums1.sort()
    
print(nums1)
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
nums1 = [1, 2, 3, 0, 0, 0]
nums2 = [2, 5, 6]
m, n = 3, 3

# Start pointers at the last valid elements of each array
p1 = m - 1  # points to last real element in nums1
p2 = n - 1  # points to last element in nums2
p = m + n - 1  # points to last position in nums1

while p1 >= 0 and p2 >= 0:
    if nums1[p1] > nums2[p2]:
        nums1[p] = nums1[p1]
        p1 -= 1
    else:
        nums1[p] = nums2[p2]
        p2 -= 1
    p -= 1

# If nums2 still has elements left, copy them over
while p2 >= 0:
    nums1[p] = nums2[p2]
    p2 -= 1
    p -= 1

print(nums1)  # [1, 2, 2, 3, 5, 6]
# Out:
# [1, 2, 2, 3, 5, 6]
