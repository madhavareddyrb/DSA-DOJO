# %%
array = [1,2,3,4,5,6,7]

for j in range(3):
	for i in range(-1,-2,-1):
		print(i)
		print(array[i])
		array.insert(0, array[i])
		array.pop()


print(array)
# Out:
# -1
# 7
# -1
# 6
# -1
# 5
# [5, 6, 7, 1, 2, 3, 4]
