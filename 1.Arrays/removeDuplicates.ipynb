# %% [markdown]
# Remove Duplicates in-place from Sorted Array
#
# Problem Statement: Given an integer array sorted in non-decreasing order, remove the duplicates in place such that each unique element appears only once. The relative order of the elements should be kept the same.
#
# If there are k elements after removing the duplicates, then the first k elements of the array should hold the final result. It does not matter what you leave beyond the first k elements.
#
# Examples
# Input: arr[]=[1,1,2,2,2,3,3]
# Output: [1,2,3,_,_,_,_]
# Explanation: Total number of unique elements are 3, i.e[1,2,3] and Therefore return 3 after assigning [1,2,3] in the beginning of the array.
#
# STEPS:
# 1. find unique elemens from arr and  insert them one by one using for loop take one extra list
# 2. save the unique in extra list
# 3. add spaces or underscores

# %%
def removeDuplicates(arr):
    newList = []
    for i in arr:
        if i not in newList:
            newList.append(i)

    for i in range(len(arr) - len(newList)):
        newList.append("_")

    return newList


arr = [1, 1, 2, 2, 2, 3, 3, 3, 3]
print(removeDuplicates(arr))
# Out:
# 9 9 auud
# [1, 2, 3, '_', '_', '_', '_', '_', '_']

# %%
# Out:
# k = 5
# Array after removing duplicates: [0, 1, 2, 3, 4]
